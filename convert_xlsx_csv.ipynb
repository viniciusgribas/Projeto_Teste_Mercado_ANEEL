# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Dados/RelSAMPClasseConsNivel.xlsx")

# %%
df.head()
# Out:
#     Ano  Mes             DescClasseConsumo                  NomeAgente  \
# 0  2009    8  Comercial, Serviços e Outras  AME - AMAZONAS ENERGIA S.A
# 1  2009    8  Comercial, Serviços e Outras  AME - AMAZONAS ENERGIA S.A
# 2  2009    8               Consumo Próprio  AME - AMAZONAS ENERGIA S.A
# 3  2009    8               Consumo Próprio  AME - AMAZONAS ENERGIA S.A
# 4  2009    8            Iluminação Pública  AME - AMAZONAS ENERGIA S.A
#
#                                    FaixaTensao  ConsumoEnergiaEletricaMWh  \
# 0                             A4 (2,3 a 25 kV)                   41533.57
# 1                          B3 - Demais Classes                   24082.58
# 2                             A4 (2,3 a 25 kV)                     384.92
# 3                          B3 - Demais Classes                     708.64
# 4  B4b - Iluminação Pública - Bulbo de Lâmpada                    6599.24
#
#    ReceitaFornecimentoEE  NumeroUnidadesConsumidoras  \
# ...

# %%
df.to_csv("Dados/SampClasse.csv", sep='|')

# %%
df_csv = pd.read_csv("Dados/SampClasse.csv", sep='|')

# %%
df_csv.head()
# Out:
#    Unnamed: 0   Ano  Mes             DescClasseConsumo  \
# 0           0  2009    8  Comercial, Serviços e Outras
# 1           1  2009    8  Comercial, Serviços e Outras
# 2           2  2009    8               Consumo Próprio
# 3           3  2009    8               Consumo Próprio
# 4           4  2009    8            Iluminação Pública
#
#                    NomeAgente                                  FaixaTensao  \
# 0  AME - AMAZONAS ENERGIA S.A                             A4 (2,3 a 25 kV)
# 1  AME - AMAZONAS ENERGIA S.A                          B3 - Demais Classes
# 2  AME - AMAZONAS ENERGIA S.A                             A4 (2,3 a 25 kV)
# 3  AME - AMAZONAS ENERGIA S.A                          B3 - Demais Classes
# 4  AME - AMAZONAS ENERGIA S.A  B4b - Iluminação Pública - Bulbo de Lâmpada
#
#    ConsumoEnergiaEletricaMWh  ReceitaFornecimentoEE  \
# 0                   41533.57            13046417.92
# 1                   24082.58             8100549.72
# ...
